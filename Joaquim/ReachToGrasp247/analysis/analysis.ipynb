# %%
import harp
import matplotlib.pyplot as plt

filename = "C:\\Users\\hgmar\\Desktop\\Joaquim\\ReachToGrasp247\\data\\Behavior"
reader = harp.create_reader(filename)

plt.figure()
digital_data = reader.Camera0Frame.read('behavior_data.bin')		# Read DigitalInputState structure
print(digital_data)
print(digital_data.shape)

digital_data['FrameAcquired'].astype(int).plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 8
#       5 reader = harp.create_reader(filename)
#       7 plt.figure()
# ----> 8 digital_data = reader.Camera0Frame.read('Behavior\\behavior_data.bin')		# Read DigitalInputState structure
#       9 print(digital_data)
#      10 print(digital_data.shape)
#
# File c:\Users\hgmar\.conda\envs\LBP-Torch\lib\site-packages\harp\reader.py:90, in _compose_parser.<locals>.parser(data, columns, epoch, keep_type)
#      84 def parser(
#      85     data: Optional[Union[_FileLike, _BufferLike]] = None,
#      86     columns: Optional[Axes] = None,
#      87     epoch: Optional[datetime] = params.epoch,
#      88     keep_type: bool = params.keep_type,
#      89 ):
# ---> 90     df = g(data, columns, epoch, keep_type)
#      91     result = f(df)
#      92     type_col = df.get(MessageType.__name__)
#
# ...
